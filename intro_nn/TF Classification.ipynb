# %% [markdown]
# ## Classification in Tensorflow
# - Data: Pima Indians Diabetes Dataset
# - tf.estimator API
# - Categorical and Continous Features
# - LinearClassifier and DNNClassifier

# %%
import pandas as pd

# %%
diabetes = pd.read_csv("pima-indians-diabetes.csv")

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features
#
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Conversion Continous -> Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes["Age"].hist(bins=20)

# %%
# continous to categories 
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20, 30, 40, 50, 60, 70, 80])

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Functions

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\dilet\AppData\Local\Temp\tmpa1vceial
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\dilet\\AppData\\Local\\Temp\\tmpa1vceial', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000168FC0B8688>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# WARNING:tensorflow:From c:\windows\system32\dl_13\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From c:\windows\system32\dl_13\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From c:\windows\system32\dl_13\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From c:\windows\system32\dl_13\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py:305: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From c:\windows\system32\dl_13\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\windows\system32\dl_13\lib\site-packages\tensorflow_core\python\ops\embedding_ops.py:802: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From c:\windows\system32\dl_13\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py:308: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From c:\windows\system32\dl_13\lib\site-packages\tensorflow_core\python\training\monitored_session.py:882: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\dilet\AppData\Local\Temp\tmpa1vceial\model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 428.106
# INFO:tensorflow:loss = 5.816208, step = 101 (0.235 sec)
# INFO:tensorflow:global_step/sec: 654.053
# INFO:tensorflow:loss = 7.5347314, step = 201 (0.152 sec)
# INFO:tensorflow:global_step/sec: 742.271
# INFO:tensorflow:loss = 7.2916713, step = 301 (0.135 sec)
# INFO:tensorflow:global_step/sec: 731.861
# INFO:tensorflow:loss = 6.279763, step = 401 (0.137 sec)
# INFO:tensorflow:global_step/sec: 675.553
# INFO:tensorflow:loss = 6.012476, step = 501 (0.148 sec)
# INFO:tensorflow:global_step/sec: 665.811
# INFO:tensorflow:loss = 4.152954, step = 601 (0.150 sec)
# INFO:tensorflow:global_step/sec: 728.035
# INFO:tensorflow:loss = 5.4379807, step = 701 (0.137 sec)
# INFO:tensorflow:global_step/sec: 723.595
# INFO:tensorflow:loss = 4.1479616, step = 801 (0.139 sec)
# INFO:tensorflow:global_step/sec: 715.318
# INFO:tensorflow:loss = 4.149231, step = 901 (0.139 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\dilet\AppData\Local\Temp\tmpa1vceial\model.ckpt.
# INFO:tensorflow:Loss for final step: 5.8523674.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From c:\windows\system32\dl_13\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:2026: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-20T20:55:16Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\dilet\AppData\Local\Temp\tmpa1vceial\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-20-20:55:17
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7322835, accuracy_baseline = 0.65748036, auc = 0.78560126, auc_precision_recall = 0.62634444, average_loss = 0.5318215, global_step = 1000, label/mean = 0.34251967, loss = 5.195487, precision = 0.63380283, prediction/mean = 0.34815267, recall = 0.51724136
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\dilet\AppData\Local\Temp\tmpa1vceial\model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.7322835,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.78560126,
#  'auc_precision_recall': 0.62634444,
#  'average_loss': 0.5318215,
#  'label/mean': 0.34251967,
#  'loss': 5.195487,
#  'precision': 0.63380283,
#  'prediction/mean': 0.34815267,
#  'recall': 0.51724136,
#  'global_step': 1000}

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\dilet\AppData\Local\Temp\tmpa1vceial\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.02879667], dtype=float32),
#   'logistic': array([0.5071987], dtype=float32),
#   'probabilities': array([0.49280134, 0.5071987 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.40862548], dtype=float32),
#   'logistic': array([0.60075825], dtype=float32),
#   'probabilities': array([0.39924175, 0.60075825], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.58793133], dtype=float32),
#   'logistic': array([0.35710967], dtype=float32),
#   'probabilities': array([0.64289033, 0.3571096 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8903211], dtype=float32),
#   'logistic': array([0.29104358], dtype=float32),
#   'probabilities': array([0.7089564 , 0.29104358], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9045835], dtype=float32),
#   'logistic': array([0.12959057], dtype=float32),
#   'probabilities': array([0.87040937, 0.1295906 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.61272764], dtype=float32),
#   'logistic': array([0.6485627], dtype=float32),
#   'probabilities': array([0.35143724, 0.6485627 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.27056968], dtype=float32),
#   'logistic': array([0.5672327], dtype=float32),
#   'probabilities': array([0.43276724, 0.5672328 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6569649], dtype=float32),
#   'logistic': array([0.34142175], dtype=float32),
#   'probabilities': array([0.6585783 , 0.34142175], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2671696], dtype=float32),
#   'logistic': array([0.21974216], dtype=float32),
#   'probabilities': array([0.7802578 , 0.21974216], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2062647], dtype=float32),
#   'logistic': array([0.23036262], dtype=float32),
#   'probabilities': array([0.7696374 , 0.23036265], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9588809], dtype=float32),
#   'logistic': array([0.12358823], dtype=float32),
#   'probabilities': array([0.8764118 , 0.12358821], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8210857], dtype=float32),
#   'logistic': array([0.13930362], dtype=float32),
#   'probabilities': array([0.8606963 , 0.13930365], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.013503], dtype=float32),
#   'logistic': array([0.2662949], dtype=float32),
#   'probabilities': array([0.73370516, 0.2662949 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.26476943], dtype=float32),
#   'logistic': array([0.56580836], dtype=float32),
#   'probabilities': array([0.43419164, 0.56580836], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6466286], dtype=float32),
#   'logistic': array([0.16156512], dtype=float32),
#   'probabilities': array([0.8384349 , 0.16156512], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.91967344], dtype=float32),
#   'logistic': array([0.28502446], dtype=float32),
#   'probabilities': array([0.71497554, 0.28502443], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.72763705], dtype=float32),
#   'logistic': array([0.32571352], dtype=float32),
#   'probabilities': array([0.67428654, 0.3257135 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9744546], dtype=float32),
#   'logistic': array([0.1219112], dtype=float32),
#   'probabilities': array([0.87808883, 0.12191123], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.72473764], dtype=float32),
#   'logistic': array([0.32635057], dtype=float32),
#   'probabilities': array([0.67364943, 0.32635057], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9310738], dtype=float32),
#   'logistic': array([0.12663178], dtype=float32),
#   'probabilities': array([0.8733682 , 0.12663178], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3883678], dtype=float32),
#   'logistic': array([0.19966844], dtype=float32),
#   'probabilities': array([0.80033153, 0.19966845], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.967778], dtype=float32),
#   'logistic': array([0.2753236], dtype=float32),
#   'probabilities': array([0.7246764, 0.2753236], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5802717], dtype=float32),
#   'logistic': array([0.6411299], dtype=float32),
#   'probabilities': array([0.35887006, 0.6411299 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.439761], dtype=float32),
#   'logistic': array([0.19158235], dtype=float32),
#   'probabilities': array([0.8084177 , 0.19158237], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7081023], dtype=float32),
#   'logistic': array([0.15340999], dtype=float32),
#   'probabilities': array([0.84659   , 0.15341002], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0009146], dtype=float32),
#   'logistic': array([0.73123837], dtype=float32),
#   'probabilities': array([0.26876163, 0.7312383 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5884972], dtype=float32),
#   'logistic': array([0.16959545], dtype=float32),
#   'probabilities': array([0.8304045 , 0.16959544], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9104221], dtype=float32),
#   'logistic': array([0.28691348], dtype=float32),
#   'probabilities': array([0.71308655, 0.28691348], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.2137108], dtype=float32),
#   'logistic': array([0.09852599], dtype=float32),
#   'probabilities': array([0.90147406, 0.098526  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.30255938], dtype=float32),
#   'logistic': array([0.57506806], dtype=float32),
#   'probabilities': array([0.42493194, 0.57506806], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.5883143], dtype=float32),
#   'logistic': array([0.93010575], dtype=float32),
#   'probabilities': array([0.06989429, 0.93010575], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.49497914], dtype=float32),
#   'logistic': array([0.37872133], dtype=float32),
#   'probabilities': array([0.6212787 , 0.37872133], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9327739], dtype=float32),
#   'logistic': array([0.28236228], dtype=float32),
#   'probabilities': array([0.7176377 , 0.28236228], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.18444479], dtype=float32),
#   'logistic': array([0.54598093], dtype=float32),
#   'probabilities': array([0.4540191 , 0.54598093], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3152568], dtype=float32),
#   'logistic': array([0.21160853], dtype=float32),
#   'probabilities': array([0.7883915 , 0.21160851], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5912902], dtype=float32),
#   'logistic': array([0.3563389], dtype=float32),
#   'probabilities': array([0.6436611, 0.3563389], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.00840342], dtype=float32),
#   'logistic': array([0.5021008], dtype=float32),
#   'probabilities': array([0.49789914, 0.5021008 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4604144], dtype=float32),
#   'logistic': array([0.61311245], dtype=float32),
#   'probabilities': array([0.3868875 , 0.61311245], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0504134], dtype=float32),
#   'logistic': array([0.7408542], dtype=float32),
#   'probabilities': array([0.2591457, 0.7408542], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.81021106], dtype=float32),
#   'logistic': array([0.3078455], dtype=float32),
#   'probabilities': array([0.6921545 , 0.30784556], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5856457], dtype=float32),
#   'logistic': array([0.16999736], dtype=float32),
#   'probabilities': array([0.8300026 , 0.16999741], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.09571648], dtype=float32),
#   'logistic': array([0.5239109], dtype=float32),
#   'probabilities': array([0.4760891, 0.5239108], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8852806], dtype=float32),
#   'logistic': array([0.13178349], dtype=float32),
#   'probabilities': array([0.8682165 , 0.13178352], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.02870429], dtype=float32),
#   'logistic': array([0.50717556], dtype=float32),
#   'probabilities': array([0.4928244 , 0.50717556], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9743229], dtype=float32),
#   'logistic': array([0.12192529], dtype=float32),
#   'probabilities': array([0.87807465, 0.12192531], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1700926], dtype=float32),
#   'logistic': array([0.10246846], dtype=float32),
#   'probabilities': array([0.89753145, 0.10246852], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.28678882], dtype=float32),
#   'logistic': array([0.5712098], dtype=float32),
#   'probabilities': array([0.4287902, 0.5712098], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.622078], dtype=float32),
#   'logistic': array([0.16491851], dtype=float32),
#   'probabilities': array([0.83508146, 0.16491848], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.562542], dtype=float32),
#   'logistic': array([0.1732822], dtype=float32),
#   'probabilities': array([0.8267178 , 0.17328219], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0227342], dtype=float32),
#   'logistic': array([0.11683657], dtype=float32),
#   'probabilities': array([0.88316345, 0.11683657], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7191622], dtype=float32),
#   'logistic': array([0.15197906], dtype=float32),
#   'probabilities': array([0.84802085, 0.1519791 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1957183], dtype=float32),
#   'logistic': array([0.23223782], dtype=float32),
#   'probabilities': array([0.7677622 , 0.23223777], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2213272], dtype=float32),
#   'logistic': array([0.22770298], dtype=float32),
#   'probabilities': array([0.77229697, 0.22770296], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5904602], dtype=float32),
#   'logistic': array([0.3565293], dtype=float32),
#   'probabilities': array([0.6434707 , 0.35652927], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0693412], dtype=float32),
#   'logistic': array([0.11211261], dtype=float32),
#   'probabilities': array([0.88788736, 0.1121126 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4042845], dtype=float32),
#   'logistic': array([0.19713712], dtype=float32),
#   'probabilities': array([0.80286294, 0.19713713], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4722078], dtype=float32),
#   'logistic': array([0.18660724], dtype=float32),
#   'probabilities': array([0.81339276, 0.18660729], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4002047], dtype=float32),
#   'logistic': array([0.19778362], dtype=float32),
#   'probabilities': array([0.80221635, 0.19778363], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.17006546], dtype=float32),
#   'logistic': array([0.45758584], dtype=float32),
#   'probabilities': array([0.5424142, 0.4575858], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.775595], dtype=float32),
#   'logistic': array([0.14484793], dtype=float32),
#   'probabilities': array([0.8551521 , 0.14484791], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2784045], dtype=float32),
#   'logistic': array([0.21782196], dtype=float32),
#   'probabilities': array([0.7821781 , 0.21782196], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.54753554], dtype=float32),
#   'logistic': array([0.63356364], dtype=float32),
#   'probabilities': array([0.36643636, 0.63356364], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.46605766], dtype=float32),
#   'logistic': array([0.6144502], dtype=float32),
#   'probabilities': array([0.38554975, 0.6144502 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.003474], dtype=float32),
#   'logistic': array([0.5008685], dtype=float32),
#   'probabilities': array([0.4991315, 0.5008685], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7599216], dtype=float32),
#   'logistic': array([0.3186633], dtype=float32),
#   'probabilities': array([0.6813367, 0.3186633], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.26017433], dtype=float32),
#   'logistic': array([0.43532085], dtype=float32),
#   'probabilities': array([0.56467915, 0.43532085], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6113479], dtype=float32),
#   'logistic': array([0.1664016], dtype=float32),
#   'probabilities': array([0.83359843, 0.16640157], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.595053], dtype=float32),
#   'logistic': array([0.16867417], dtype=float32),
#   'probabilities': array([0.8313258 , 0.16867417], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7763253], dtype=float32),
#   'logistic': array([0.14475746], dtype=float32),
#   'probabilities': array([0.85524255, 0.14475746], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.082316], dtype=float32),
#   'logistic': array([0.11082754], dtype=float32),
#   'probabilities': array([0.8891725 , 0.11082754], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.32897735], dtype=float32),
#   'logistic': array([0.58151054], dtype=float32),
#   'probabilities': array([0.4184895 , 0.58151054], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3700387], dtype=float32),
#   'logistic': array([0.20261359], dtype=float32),
#   'probabilities': array([0.7973864 , 0.20261358], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4006309], dtype=float32),
#   'logistic': array([0.40116078], dtype=float32),
#   'probabilities': array([0.5988392 , 0.40116078], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.25466466], dtype=float32),
#   'logistic': array([0.5633243], dtype=float32),
#   'probabilities': array([0.4366757, 0.5633243], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9770845], dtype=float32),
#   'logistic': array([0.27347067], dtype=float32),
#   'probabilities': array([0.72652936, 0.27347067], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.46601868], dtype=float32),
#   'logistic': array([0.614441], dtype=float32),
#   'probabilities': array([0.385559  , 0.61444104], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0377097], dtype=float32),
#   'logistic': array([0.11530018], dtype=float32),
#   'probabilities': array([0.8846998 , 0.11530014], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.34450555], dtype=float32),
#   'logistic': array([0.58528453], dtype=float32),
#   'probabilities': array([0.41471544, 0.5852846 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.021802], dtype=float32),
#   'logistic': array([0.11693279], dtype=float32),
#   'probabilities': array([0.88306725, 0.11693279], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.13683617], dtype=float32),
#   'logistic': array([0.5341558], dtype=float32),
#   'probabilities': array([0.46584427, 0.5341558 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8945313], dtype=float32),
#   'logistic': array([0.29017562], dtype=float32),
#   'probabilities': array([0.7098244 , 0.29017562], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7910339], dtype=float32),
#   'logistic': array([0.14294598], dtype=float32),
#   'probabilities': array([0.857054  , 0.14294602], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.17991042], dtype=float32),
#   'logistic': array([0.54485667], dtype=float32),
#   'probabilities': array([0.4551433 , 0.54485667], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.22743416], dtype=float32),
#   'logistic': array([0.5566147], dtype=float32),
#   'probabilities': array([0.44338524, 0.5566147 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.00800753], dtype=float32),
#   'logistic': array([0.5020019], dtype=float32),
#   'probabilities': array([0.49799812, 0.5020019 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6709394], dtype=float32),
#   'logistic': array([0.15829897], dtype=float32),
#   'probabilities': array([0.84170103, 0.15829897], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7218672], dtype=float32),
#   'logistic': array([0.32698196], dtype=float32),
#   'probabilities': array([0.67301804, 0.32698193], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8010364], dtype=float32),
#   'logistic': array([0.14172494], dtype=float32),
#   'probabilities': array([0.85827506, 0.14172496], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7210922], dtype=float32),
#   'logistic': array([0.6728475], dtype=float32),
#   'probabilities': array([0.32715252, 0.6728475 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2568355], dtype=float32),
#   'logistic': array([0.7784809], dtype=float32),
#   'probabilities': array([0.22151913, 0.7784809 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.38741696], dtype=float32),
#   'logistic': array([0.59566075], dtype=float32),
#   'probabilities': array([0.40433925, 0.59566075], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4521546], dtype=float32),
#   'logistic': array([0.18967018], dtype=float32),
#   'probabilities': array([0.8103298 , 0.18967018], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.27743328], dtype=float32),
#   'logistic': array([0.43108317], dtype=float32),
#   'probabilities': array([0.5689168, 0.4310831], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6074342], dtype=float32),
#   'logistic': array([0.35264474], dtype=float32),
#   'probabilities': array([0.6473553, 0.3526447], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.30661154], dtype=float32),
#   'logistic': array([0.42394206], dtype=float32),
#   'probabilities': array([0.576058  , 0.42394203], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7054237], dtype=float32),
#   'logistic': array([0.33061084], dtype=float32),
#   'probabilities': array([0.6693892, 0.3306108], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.24634004], dtype=float32),
#   'logistic': array([0.43872455], dtype=float32),
#   'probabilities': array([0.5612755 , 0.43872458], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8486869], dtype=float32),
#   'logistic': array([0.13602713], dtype=float32),
#   'probabilities': array([0.86397284, 0.13602713], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.19022202], dtype=float32),
#   'logistic': array([0.54741263], dtype=float32),
#   'probabilities': array([0.4525874 , 0.54741263], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.17004323], dtype=float32),
#   'logistic': array([0.54240865], dtype=float32),
#   'probabilities': array([0.4575913 , 0.54240865], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2974706], dtype=float32),
#   'logistic': array([0.21459103], dtype=float32),
#   'probabilities': array([0.78540903, 0.21459106], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7103996], dtype=float32),
#   'logistic': array([0.15311188], dtype=float32),
#   'probabilities': array([0.8468881 , 0.15311189], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6475205], dtype=float32),
#   'logistic': array([0.16144437], dtype=float32),
#   'probabilities': array([0.83855563, 0.16144434], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.123003], dtype=float32),
#   'logistic': array([0.2454547], dtype=float32),
#   'probabilities': array([0.75454533, 0.24545468], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.53545326], dtype=float32),
#   'logistic': array([0.36924592], dtype=float32),
#   'probabilities': array([0.6307541 , 0.36924592], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0163183], dtype=float32),
#   'logistic': array([0.11750022], dtype=float32),
#   'probabilities': array([0.8824998 , 0.11750023], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.82872194], dtype=float32),
#   'logistic': array([0.3039154], dtype=float32),
#   'probabilities': array([0.6960847, 0.3039154], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2326206], dtype=float32),
#   'logistic': array([0.22572312], dtype=float32),
#   'probabilities': array([0.7742769 , 0.22572309], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.2816691], dtype=float32),
#   'logistic': array([0.09265254], dtype=float32),
#   'probabilities': array([0.9073475 , 0.09265254], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0219975], dtype=float32),
#   'logistic': array([0.1169126], dtype=float32),
#   'probabilities': array([0.8830874, 0.1169126], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.91907644], dtype=float32),
#   'logistic': array([0.7148539], dtype=float32),
#   'probabilities': array([0.28514612, 0.7148539 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6097567], dtype=float32),
#   'logistic': array([0.1666224], dtype=float32),
#   'probabilities': array([0.8333776, 0.1666224], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0403657], dtype=float32),
#   'logistic': array([0.11502945], dtype=float32),
#   'probabilities': array([0.8849705 , 0.11502951], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8531663], dtype=float32),
#   'logistic': array([0.13550156], dtype=float32),
#   'probabilities': array([0.86449844, 0.13550156], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2289387], dtype=float32),
#   'logistic': array([0.44301403], dtype=float32),
#   'probabilities': array([0.556986  , 0.44301397], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2334075], dtype=float32),
#   'logistic': array([0.4419116], dtype=float32),
#   'probabilities': array([0.5580884, 0.4419116], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2488997], dtype=float32),
#   'logistic': array([0.22289068], dtype=float32),
#   'probabilities': array([0.7771094 , 0.22289068], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.37793398], dtype=float32),
#   'logistic': array([0.4066253], dtype=float32),
#   'probabilities': array([0.59337467, 0.40662527], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6750743], dtype=float32),
#   'logistic': array([0.15774882], dtype=float32),
#   'probabilities': array([0.8422512 , 0.15774882], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3669956], dtype=float32),
#   'logistic': array([0.20310569], dtype=float32),
#   'probabilities': array([0.79689425, 0.20310567], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.14758551], dtype=float32),
#   'logistic': array([0.46317047], dtype=float32),
#   'probabilities': array([0.53682953, 0.46317044], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2290209], dtype=float32),
#   'logistic': array([0.44299373], dtype=float32),
#   'probabilities': array([0.5570063 , 0.44299376], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.995554], dtype=float32),
#   'logistic': array([0.11967051], dtype=float32),
#   'probabilities': array([0.8803295 , 0.11967053], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.51936805], dtype=float32),
#   'logistic': array([0.37300003], dtype=float32),
#   'probabilities': array([0.62700003, 0.37300006], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.66018224], dtype=float32),
#   'logistic': array([0.65930134], dtype=float32),
#   'probabilities': array([0.34069866, 0.65930134], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.03745151], dtype=float32),
#   'logistic': array([0.49063823], dtype=float32),
#   'probabilities': array([0.5093618 , 0.49063823], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5934402], dtype=float32),
#   'logistic': array([0.35584593], dtype=float32),
#   'probabilities': array([0.6441541, 0.3558459], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.06222892], dtype=float32),
#   'logistic': array([0.5155522], dtype=float32),
#   'probabilities': array([0.4844478, 0.5155522], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.259028], dtype=float32),
#   'logistic': array([0.22114126], dtype=float32),
#   'probabilities': array([0.7788588 , 0.22114128], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6234694], dtype=float32),
#   'logistic': array([0.16472696], dtype=float32),
#   'probabilities': array([0.835273  , 0.16472696], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.043518], dtype=float32),
#   'logistic': array([0.11470896], dtype=float32),
#   'probabilities': array([0.88529104, 0.11470899], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1356328], dtype=float32),
#   'logistic': array([0.24312311], dtype=float32),
#   'probabilities': array([0.75687695, 0.2431231 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.14300203], dtype=float32),
#   'logistic': array([0.4643103], dtype=float32),
#   'probabilities': array([0.5356897 , 0.46431032], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.65354645], dtype=float32),
#   'logistic': array([0.6578092], dtype=float32),
#   'probabilities': array([0.34219077, 0.6578092 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3229144], dtype=float32),
#   'logistic': array([0.21033385], dtype=float32),
#   'probabilities': array([0.7896662 , 0.21033382], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.734981], dtype=float32),
#   'logistic': array([0.14995158], dtype=float32),
#   'probabilities': array([0.8500485 , 0.14995158], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.46222794], dtype=float32),
#   'logistic': array([0.38645744], dtype=float32),
#   'probabilities': array([0.61354256, 0.3864574 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2982324], dtype=float32),
#   'logistic': array([0.21446261], dtype=float32),
#   'probabilities': array([0.78553736, 0.21446265], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8364657], dtype=float32),
#   'logistic': array([0.13746981], dtype=float32),
#   'probabilities': array([0.8625302 , 0.13746981], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6160834], dtype=float32),
#   'logistic': array([0.16574572], dtype=float32),
#   'probabilities': array([0.8342543 , 0.16574575], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0048153], dtype=float32),
#   'logistic': array([0.11869827], dtype=float32),
#   'probabilities': array([0.88130176, 0.11869827], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6039184], dtype=float32),
#   'logistic': array([0.35344777], dtype=float32),
#   'probabilities': array([0.64655226, 0.35344774], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0737281], dtype=float32),
#   'logistic': array([0.74530524], dtype=float32),
#   'probabilities': array([0.25469476, 0.74530524], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
# ...
#  {'logits': array([0.6952903], dtype=float32),
#   'logistic': array([0.66714275], dtype=float32),
#   'probabilities': array([0.33285728, 0.6671428 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.39706194], dtype=float32),
#   'logistic': array([0.5979816], dtype=float32),
#   'probabilities': array([0.40201843, 0.5979816 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.71301866], dtype=float32),
#   'logistic': array([0.67106783], dtype=float32),
#   'probabilities': array([0.3289322 , 0.67106783], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.3100413], dtype=float32),
#   'logistic': array([0.42310464], dtype=float32),
#   'probabilities': array([0.57689536, 0.42310467], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.92985076], dtype=float32),
#   'logistic': array([0.282955], dtype=float32),
#   'probabilities': array([0.717045, 0.282955], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.0589267], dtype=float32),
#   'logistic': array([0.4852726], dtype=float32),
#   'probabilities': array([0.5147274, 0.4852726], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5687698], dtype=float32),
#   'logistic': array([0.1723918], dtype=float32),
#   'probabilities': array([0.82760817, 0.17239183], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8148882], dtype=float32),
#   'logistic': array([0.14004841], dtype=float32),
#   'probabilities': array([0.8599516 , 0.14004837], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5716033], dtype=float32),
#   'logistic': array([0.17198795], dtype=float32),
#   'probabilities': array([0.82801205, 0.17198795], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.09075052], dtype=float32),
#   'logistic': array([0.47732794], dtype=float32),
#   'probabilities': array([0.5226721 , 0.47732797], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.779767], dtype=float32),
#   'logistic': array([0.05842736], dtype=float32),
#   'probabilities': array([0.9415726 , 0.05842737], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0320998], dtype=float32),
#   'logistic': array([0.26267725], dtype=float32),
#   'probabilities': array([0.73732275, 0.2626772 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7347977], dtype=float32),
#   'logistic': array([0.14997493], dtype=float32),
#   'probabilities': array([0.85002506, 0.14997493], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0969381], dtype=float32),
#   'logistic': array([0.25031403], dtype=float32),
#   'probabilities': array([0.74968594, 0.25031403], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2254822], dtype=float32),
#   'logistic': array([0.22697315], dtype=float32),
#   'probabilities': array([0.7730269 , 0.22697313], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0822799], dtype=float32),
#   'logistic': array([0.25307482], dtype=float32),
#   'probabilities': array([0.74692523, 0.25307482], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1548309], dtype=float32),
#   'logistic': array([0.7603922], dtype=float32),
#   'probabilities': array([0.2396078, 0.7603922], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7240121], dtype=float32),
#   'logistic': array([0.15135509], dtype=float32),
#   'probabilities': array([0.8486449, 0.1513551], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1245446], dtype=float32),
#   'logistic': array([0.10673398], dtype=float32),
#   'probabilities': array([0.89326596, 0.106734  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2099402], dtype=float32),
#   'logistic': array([0.5522931], dtype=float32),
#   'probabilities': array([0.44770688, 0.5522931 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.221519], dtype=float32),
#   'logistic': array([0.44484562], dtype=float32),
#   'probabilities': array([0.5551544, 0.4448456], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.591744], dtype=float32),
#   'logistic': array([0.83086133], dtype=float32),
#   'probabilities': array([0.16913868, 0.83086133], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.40882432], dtype=float32),
#   'logistic': array([0.60080594], dtype=float32),
#   'probabilities': array([0.39919406, 0.60080594], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.109151], dtype=float32),
#   'logistic': array([0.10821058], dtype=float32),
#   'probabilities': array([0.8917894 , 0.10821057], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.46564674], dtype=float32),
#   'logistic': array([0.6143529], dtype=float32),
#   'probabilities': array([0.38564712, 0.6143529 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.09320498], dtype=float32),
#   'logistic': array([0.5232844], dtype=float32),
#   'probabilities': array([0.47671565, 0.52328444], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0862641], dtype=float32),
#   'logistic': array([0.74767756], dtype=float32),
#   'probabilities': array([0.25232244, 0.74767756], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2920495], dtype=float32),
#   'logistic': array([0.21550614], dtype=float32),
#   'probabilities': array([0.78449386, 0.2155061 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6549413], dtype=float32),
#   'logistic': array([0.16044223], dtype=float32),
#   'probabilities': array([0.8395578 , 0.16044225], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.00543284], dtype=float32),
#   'logistic': array([0.4986418], dtype=float32),
#   'probabilities': array([0.5013582, 0.4986418], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8017211], dtype=float32),
#   'logistic': array([0.14164165], dtype=float32),
#   'probabilities': array([0.8583583 , 0.14164169], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1345897], dtype=float32),
#   'logistic': array([0.7566849], dtype=float32),
#   'probabilities': array([0.24331509, 0.7566849 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.04608583], dtype=float32),
#   'logistic': array([0.48848054], dtype=float32),
#   'probabilities': array([0.51151943, 0.4884806 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7440822], dtype=float32),
#   'logistic': array([0.14879516], dtype=float32),
#   'probabilities': array([0.8512048 , 0.14879514], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.07218671], dtype=float32),
#   'logistic': array([0.51803887], dtype=float32),
#   'probabilities': array([0.4819611, 0.5180388], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.22568995], dtype=float32),
#   'logistic': array([0.4438158], dtype=float32),
#   'probabilities': array([0.5561842 , 0.44381577], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1837792], dtype=float32),
#   'logistic': array([0.10121661], dtype=float32),
#   'probabilities': array([0.8987834, 0.1012166], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.00647593], dtype=float32),
#   'logistic': array([0.501619], dtype=float32),
#   'probabilities': array([0.49838102, 0.501619  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.30601406], dtype=float32),
#   'logistic': array([0.57591206], dtype=float32),
#   'probabilities': array([0.42408797, 0.57591206], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.97879505], dtype=float32),
#   'logistic': array([0.72686905], dtype=float32),
#   'probabilities': array([0.27313092, 0.72686905], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2129064], dtype=float32),
#   'logistic': array([0.77081275], dtype=float32),
#   'probabilities': array([0.22918722, 0.7708128 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4019128], dtype=float32),
#   'logistic': array([0.40085286], dtype=float32),
#   'probabilities': array([0.59914714, 0.40085286], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7400175], dtype=float32),
#   'logistic': array([0.14931071], dtype=float32),
#   'probabilities': array([0.8506893 , 0.14931071], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.5301518], dtype=float32),
#   'logistic': array([0.07377127], dtype=float32),
#   'probabilities': array([0.9262287 , 0.07377127], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.270586], dtype=float32),
#   'logistic': array([0.09358849], dtype=float32),
#   'probabilities': array([0.90641147, 0.09358849], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2028536], dtype=float32),
#   'logistic': array([0.23096797], dtype=float32),
#   'probabilities': array([0.769032  , 0.23096797], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7855017], dtype=float32),
#   'logistic': array([0.31313536], dtype=float32),
#   'probabilities': array([0.6868647, 0.3131354], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0731846], dtype=float32),
#   'logistic': array([0.25479794], dtype=float32),
#   'probabilities': array([0.74520206, 0.25479794], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)}]

# %% [markdown]
# ## DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\dilet\AppData\Local\Temp\tmpylgckh_b
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\dilet\\AppData\\Local\\Temp\\tmpylgckh_b', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000168FFF51748>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-cea30273f6d4> in <module>
#       1 # UH OH! AN ERROR. Check out the video to see why and how to fix.
#       2 # https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
# ----> 3 dnn_model.train(input_fn=input_func,steps=1000)
#
# c:\windows\system32\dl_13\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     368
#     369       saving_listeners = _check_listeners_type(saving_listeners)
# --> 370       loss = self._train_model(input_fn, hooks, saving_listeners)
#     371       logging.info('Loss for final step: %s.', loss)
#     372       return self
#
# c:\windows\system32\dl_13\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1159       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1160     else:
# -> 1161       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1162
#    1163   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# c:\windows\system32\dl_13\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1189       worker_hooks.extend(input_hooks)
#    1190       estimator_spec = self._call_model_fn(
# -> 1191           features, labels, ModeKeys.TRAIN, self.config)
#    1192       global_step_tensor = training_util.get_global_step(g)
#    1193       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#
# c:\windows\system32\dl_13\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1147
#    1148     logging.info('Calling model_fn.')
# -> 1149     model_fn_results = self._model_fn(features=features, **kwargs)
#    1150     logging.info('Done calling model_fn.')
#    1151
#
# c:\windows\system32\dl_13\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in _model_fn(features, labels, mode, config)
#     809           input_layer_partitioner=input_layer_partitioner,
#     810           config=config,
# --> 811           batch_norm=batch_norm)
#     812
#     813     super(DNNClassifier, self).__init__(
#
# c:\windows\system32\dl_13\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config, use_tpu, batch_norm)
#     461         input_layer_partitioner=input_layer_partitioner,
#     462         batch_norm=batch_norm)
# --> 463     logits = logit_fn(features=features, mode=mode)
#     464
#     465     return _get_dnn_estimator_spec(use_tpu, head, features, labels, mode,
#
# c:\windows\system32\dl_13\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in dnn_logit_fn(features, mode)
#     106         input_layer_partitioner,
#     107         batch_norm,
# --> 108         name='dnn')
#     109     return dnn_model(features, mode)
#     110
#
# c:\windows\system32\dl_13\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in __init__(self, units, hidden_units, feature_columns, activation_fn, dropout, input_layer_partitioner, batch_norm, name, **kwargs)
#     184     if feature_column_lib.is_feature_column_v2(feature_columns):
#     185       self._input_layer = dense_features.DenseFeatures(
# --> 186           feature_columns=feature_columns, name='input_layer')
#     187     else:
#     188       self._input_layer = feature_column.InputLayer(
#
# c:\windows\system32\dl_13\lib\site-packages\tensorflow_core\python\feature_column\dense_features.py in __init__(self, feature_columns, trainable, name, **kwargs)
#      84         name=name,
#      85         expected_column_type=fc.DenseColumn,
# ---> 86         **kwargs)
#      87
#      88   @property
#
# c:\windows\system32\dl_13\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py in __init__(self, feature_columns, expected_column_type, trainable, name, **kwargs)
#     378             'You can wrap a categorical column with an '
#     379             'embedding_column or indicator_column. Given: {}'.format(
# --> 380                 expected_column_type, column))
#     381
#     382   def build(self, _):
#
# ValueError: Items of feature_columns must be a <class 'tensorflow.python.feature_column.feature_column_v2.DenseColumn'>. You can wrap a categorical column with an embedding_column or indicator_column. Given: VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\dilet\AppData\Local\Temp\tmp5fm33ngj
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\dilet\\AppData\\Local\\Temp\\tmp5fm33ngj', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000168FED6F948>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From c:\windows\system32\dl_13\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py:3079: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From c:\windows\system32\dl_13\lib\site-packages\tensorflow_core\python\training\adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\dilet\AppData\Local\Temp\tmp5fm33ngj\model.ckpt.
# INFO:tensorflow:loss = 6.9212847, step = 1
# INFO:tensorflow:global_step/sec: 430.395
# INFO:tensorflow:loss = 5.061756, step = 101 (0.233 sec)
# INFO:tensorflow:global_step/sec: 701.172
# INFO:tensorflow:loss = 5.163851, step = 201 (0.145 sec)
# INFO:tensorflow:global_step/sec: 668.334
# INFO:tensorflow:loss = 4.5834856, step = 301 (0.152 sec)
# INFO:tensorflow:global_step/sec: 664.023
# INFO:tensorflow:loss = 3.9935527, step = 401 (0.148 sec)
# INFO:tensorflow:global_step/sec: 629.876
# INFO:tensorflow:loss = 3.2615929, step = 501 (0.157 sec)
# INFO:tensorflow:global_step/sec: 550.681
# INFO:tensorflow:loss = 5.445211, step = 601 (0.182 sec)
# INFO:tensorflow:global_step/sec: 649.205
# INFO:tensorflow:loss = 6.413306, step = 701 (0.155 sec)
# INFO:tensorflow:global_step/sec: 655.257
# INFO:tensorflow:loss = 3.5864766, step = 801 (0.152 sec)
# INFO:tensorflow:global_step/sec: 638.435
# INFO:tensorflow:loss = 5.4889708, step = 901 (0.157 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\dilet\AppData\Local\Temp\tmp5fm33ngj\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.3616579.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-20T20:57:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\dilet\AppData\Local\Temp\tmp5fm33ngj\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-20-20:57:01
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7401575, accuracy_baseline = 0.65748036, auc = 0.7939982, auc_precision_recall = 0.6120424, average_loss = 0.52409095, global_step = 1000, label/mean = 0.34251967, loss = 5.119965, precision = 0.6179775, prediction/mean = 0.36760795, recall = 0.6321839
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\dilet\AppData\Local\Temp\tmp5fm33ngj\model.ckpt-1000
# {'accuracy': 0.7401575,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.7939982,
#  'auc_precision_recall': 0.6120424,
#  'average_loss': 0.52409095,
#  'label/mean': 0.34251967,
#  'loss': 5.119965,
#  'precision': 0.6179775,
#  'prediction/mean': 0.36760795,
#  'recall': 0.6321839,
#  'global_step': 1000}
